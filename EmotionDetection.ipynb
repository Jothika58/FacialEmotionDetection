# %%
pip install deepface
# Out:
# ...
#      |████████████████████████████████| 61kB 2.4MB/s
# ...
#      |████████████████████████████████| 2.3MB 5.1MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-3.13.0-cp37-none-any.whl size=9046 sha256=d105d978d81ab8ffc2a037bf61ab58f717391d24abadc82502894a7e04c57ee9
#   Stored in directory: /root/.cache/pip/wheels/ba/fa/c5/12813d7496f34652c43a471e11a780e769889d06e34735c32e
# Successfully built gdown
# ...
#   Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
img1=cv2.imread('/content/elonimg.jpg')
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
result=DeepFace.analyze(img1, actions =['emotion'])
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://drive.google.com/uc?id=13iUHHP3SlNg53qSuQZDdHDSDNdBP9nwy
# To: /root/.deepface/weights/facial_expression_model_weights.zip
# 5.54MB [00:00, 35.1MB/s]

# %%
print(result)
# Out:
# {'emotion': {'angry': 1.6872603024147676e-13, 'disgust': 1.926677445946901e-27, 'fear': 2.8174340350227253e-16, 'happy': 99.99165534973145, 'sad': 4.180059483228568e-12, 'surprise': 5.762970989309224e-07, 'neutral': 0.008346109825652093}, 'dominant_emotion': 'happy', 'region': {'x': 645, 'y': 70, 'w': 222, 'h': 222}}
